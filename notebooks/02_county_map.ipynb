# %%
import pandas as pd

url = "https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv"
df_real = pd.read_csv(url, dtype={"fips": str})

df_real.head()
# Out:
#     fips  unemp
# 0  01001    5.3
# 1  01003    5.4
# 2  01005    8.6
# 3  01007    6.6
# 4  01009    5.5

# %% [markdown]
# # Assistant
# The error is a syntax error on line 1 of your code. The issue is that you've misspelled the import statement as "iimport" instead of "import".
#
# Would you like me to provide the corrected code?

# %%
df_real["fips"] = df_real["fips"].astype(str).str.zfill(5)
df_real.head()
# Out:
#     fips  unemp
# 0  01001    5.3
# 1  01003    5.4
# 2  01005    8.6
# 3  01007    6.6
# 4  01009    5.5

# %%
df_real.columns
# Out:
# Index(['fips', 'unemp'], dtype='object')

# %%
import plotly.express as px

fig = px.choropleth(
    df_real,
    geojson=counties,
    locations="fips",
    color="unemp",             # if your columns show a different name, tell me and we’ll swap it
    scope="usa",
    color_continuous_scale="Viridis",
    labels={"unemp": "Rate"},
)

fig.update_layout(
    title="County map (real dataset)",
    margin={"r":0,"t":50,"l":0,"b":0},
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 import plotly.express as px
#       3 fig = px.choropleth(
#       4     df_real,
# ----> 5     geojson=counties,
#       6     locations="fips",
#       7     color="unemp",             # if your columns show a different name, tell me and we’ll swap it
#       8     scope="usa",
#       9     color_continuous_scale="Viridis",
#      10     labels={"unemp": "Rate"},
#      11 )
#      13 fig.update_layout(
#      14     title="County map (real dataset)",
#      15     margin={"r":0,"t":50,"l":0,"b":0},
#      16 )
#      18 fig.show()
#
# NameError: name 'counties' is not defined

# %%
import json

with open("../data/raw/geo/geojson-counties-fips.json", "r") as f:
    counties = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 import json
# ----> 3 with open("../data/raw/geo/geojson-counties-fips.json", "r") as f:
#       4     counties = json.load(f)
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/geo/geojson-counties-fips.json'

# %%
import json

    with open("../data/raw/geo/geojson-counties-fips.json", "r") as f:
    counties = json.load(f)
# Out:
#   Cell In[10], line 3
#     with open("../data/raw/geo/geojson-counties-fips.json", "r") as f:
#     ^
# IndentationError: unexpected indent

# %%
import json

with open("../data/raw/geo/geojson-counties-fips.json", "r") as f:
    counties = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import json
# ----> 3 with open("../data/raw/geo/geojson-counties-fips.json", "r") as f:
#       4     counties = json.load(f)
#
# File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/geo/geojson-counties-fips.json'

# %%
import os
os.getcwd()
# Out:
# '/Users/zoomuser1/Desktop/hiv-need-access-eda/notebooks/notebooks'

# %%
import os

# %%
import os
os.listdir(".")
# Out:
# ['02_county_map.ipynb',
#  '.ipynb_checkpoints',
#  '01_smoke_test.ipynb',
#  '02_county_map_smoke_test.ipynb']
